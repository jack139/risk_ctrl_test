# %%
import os
import pickle
import pandas as pd
import numpy as np

# %%
path = '.'
data_path = os.path.join(path ,'data')
#########读取数据####################################################
#df_1 = pd.read_csv( os.path.join(data_path, 'LoanStats_2019Q1.csv'),header=1 ,sep=',', low_memory=False)
df_1 = pd.read_excel( os.path.join(data_path, '信用支付.xlsx'), header=0)

# %%
cols_to_drop = ['PAY_NO', 'OUT_PAY_NO', 'CHANNEL_ACCOUNT_ID', 'USER_ID', 'ACCOUNT_TYPE',
       'USER_NAME', 'MERCHANT_ID',
       'DOMAIN_ID', 'APP_CHANNEL', 'APP_ID', 'NOTIFY_URL',
       'PAY_RES_CODE', 'KEEP_TIME', 'KEEP_DATE', 'PLAN_TIME',
       'KEEP_RES_CODE', 
       'CRT_TIME', 
       'PAY_BACK_URL', 'PAY_BACK_TIME',
       'ORDER_NO', 'HOSPITAL_PAY_NO', 'CHANNEL_ID', 'OPTIONAL',
       'NOTE', 'RESERVE01', 'RESERVE02', 'PAY_DATE', 'PAY_TIME',
       'SIGN_CHANNEL', 'IS_FMP', 'FMP_USER_ID']
df_1 = df_1.drop(cols_to_drop, axis=1)

# %%
df_1
# Out:
#     PAY_CHANNEL  AMOUNT    CHARGE_NAME                 PAY_RES_NOTE  \
# 0           CFP  3000.0         综合就诊费用                         处理成功
# 1           CFP    15.0   诊间结算-皮肤科-诊察费  支付平台失败,查询信用签约失败,无开通渠道，请前往开通
# 2           CFP    15.0   诊间结算-皮肤科-诊察费  支付平台失败,查询信用签约失败,无开通渠道，请前往开通
# 3           CFP    50.0   诊间结算-皮肤科-诊察费                         处理成功
# 4           CFP    50.0  诊间结算-内分泌科-诊察费  支付平台失败,查询信用签约失败,无开通渠道，请前往开通
# ..          ...     ...            ...                          ...
# 994         CMB    20.0   诊间结算-皮肤科-诊察费                         处理成功
# 995         CMB    20.0  诊间结算-内分泌科-诊察费                         处理成功
# 996         ALI    35.0  诊间结算-特需门诊-诊察费                          NaN
# 997         ALI    35.0  诊间结算-特需门诊-诊察费                          NaN
# 998         CFP   746.0         综合就诊费用                         处理成功
#
#       PLAN_DATE                KEEP_RES_NOTE PAY_STATE KEEP_STATE TOTAL_STATE  \
# ...
